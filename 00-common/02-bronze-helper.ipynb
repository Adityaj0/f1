# %%
from pyspark.sql import functions as F

def add_ingestion_meta(df):
  return(
      df.withColumn('ingested_at', F.current_timestamp())
        .withColumn('source_file', F.col('_metadata.file_path'))

  )

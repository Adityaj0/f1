-- %%
%fs ls 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/landing'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databrickscoursedl12_formula1
    URL 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL `databricks-course-sc`);

-- %%
SHOW CATALOGS

-- %%
 CREATE CATALOG IF NOT EXISTS formula1
   MANAGED LOCATION 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/'

-- %%
CREATE SCHEMA IF NOT EXISTS formula1.landing;
CREATE SCHEMA IF NOT EXISTS formula1.bronze
    MANAGED LOCATION 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/bronze';
CREATE SCHEMA IF NOT EXISTS formula1.silver
    MANAGED LOCATION 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS formula1.gold
    MANAGED LOCATION 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/gold';

-- %%
SELECT current_catalog();

-- %%
USE CATALOG formula1;

-- %%
SHOW SCHEMAS;

-- %%
CREATE EXTERNAL VOLUME formula1.landing.files
    LOCATION 'abfss://formula1@databrickscoursedl12.dfs.core.windows.net/landing'
